# %%
from preprocessor import AzdiasPreprocessor, FeatureDropper
from pprint import pprint
import pandas as pd

import inspect
print(inspect.getsource(AzdiasPreprocessor))
# Out:
# class AzdiasPreprocessor():
#
#     def __init__(
#             self,
#             data_source,
#             summary_source,
#             na_feature_threshold=20,
#             na_sample_threshold=25,
#             cleaning_pipeline=None,
#             impute_pipeline=None,
#             scaling_pipeline=None,
#             split_data=False
#     ):
#         """
#         Initialize the preprocessor.
#         :param data_source: path to the general population data file
#         :param summary_source: path to the feature summary file
#         :param na_feature_threshold: percentage threshold for dropping high-missing features
#         :param na_sample_threshold: threshold for splitting population data by row/sample missingness
#         :param cleaning_pipeline: custom processing pipeline to apply to the data
#         :param impute_pipeline: custom impute pipeline to apply to the data
#         :param scaling_pipeline: custom scaling pipeline to apply to the data
# ...

# %%
preprocessor = AzdiasPreprocessor(
    data_source="Udacity_AZDIAS_Subset.csv",
    summary_source="AZDIAS_Feature_summary.csv",
    na_feature_threshold=20,
    na_sample_threshold=25
)
preprocessor
# Out:
# Loading data from...Udacity_AZDIAS_Subset.csv
# No pipeline parameter passed in. Building default pipeline...
# Building cleaning pipeline...

# %%
pprint(preprocessor._feature_groups)
# Out:
# {'binary': {'ANREDE_KZ',
#             'GREEN_AVANTGARDE',
#             'LP_IS_HOMEOWNER',
#             'LP_IS_INDEPENDENT',
#             'PRAEGENDE_MOVEMENT',
#             'VERS_TYP',
#             'WOHN_IS_RURAL',
#             'WOHN_NEW_BUILDING'},
#  'encoded_features': set(),
#  'engineered_categorical': {'LP_LIFE_STAGE'},
#  'engineered_features': {'CAMEO_LIFESTAGE',
#                          'CAMEO_WEALTH',
#                          'LP_AGE_CLASS',
#                          'LP_INCOME_LEVEL',
#                          'LP_IS_HOMEOWNER',
#                          'LP_IS_INDEPENDENT',
#                          'PRAEGENDE_DECADE',
#                          'PRAEGENDE_MOVEMENT',
#                          'WOHN_IS_RURAL',
#                          'WOHN_NEIGHBORHOOD_QUALITY',
#                          'WOHN_NEW_BUILDING'},
#  'features_to_drop': {'na_features': {'AGER_TYP',
#                                       'ALTER_HH',
# ...

# %%
# Test One Hot Encoder
df_test = pd.read_csv("Udacity_AZDIAS_Subset.csv", delimiter=";")

# %%
df_test.head()
# Out:
#    AGER_TYP  ALTERSKATEGORIE_GROB  ANREDE_KZ  CJT_GESAMTTYP  \
# 0        -1                     2          1            2.0
# 1        -1                     1          2            5.0
# 2        -1                     3          2            3.0
# 3         2                     4          2            2.0
# 4        -1                     3          1            5.0
#
#    FINANZ_MINIMALIST  FINANZ_SPARER  FINANZ_VORSORGER  FINANZ_ANLEGER  \
# 0                  3              4                 3               5
# 1                  1              5                 2               5
# 2                  1              4                 1               2
# 3                  4              2                 5               2
# 4                  4              3                 4               1
#
#    FINANZ_UNAUFFAELLIGER  FINANZ_HAUSBAUER  ...  PLZ8_ANTG1  PLZ8_ANTG2  \
# 0                      5                 3  ...         NaN         NaN
# ...

# %%
df_test = preprocessor.clean_data(df_test)
df_test.head()
# Out:
# [Pipeline] .. (step 1 of 2) Processing replace_missings, total=   1.8s
# Dropping Features: {'ALTER_HH', 'AGER_TYP', 'KBA05_BAUMAX', 'GEBURTSJAHR', 'TITEL_KZ', 'KK_KUNDENTYP'}
# Dropped 6 features
# Dropped Features: ['ALTER_HH', 'AGER_TYP', 'KBA05_BAUMAX', 'GEBURTSJAHR', 'TITEL_KZ', 'KK_KUNDENTYP']
# ...
